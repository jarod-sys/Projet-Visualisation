# %%
from utils_processing import*

# %% [markdown]
# # Preprocessing

# %%
cleaning_data=FillgeoLoc()

# %%
cleaning_data.build_json("sharks")

# %%
dfFloat_to_dfStr(df=cleaning_data.Data_geoLocation)
# Out:
#      Case Number         Date  Year        Type             Country  \
# 0     2019.08.27  27-Aug-2019  2019    Provoked                 USA
# 1     2019.08.21  21-Aug-2019  2019  Unprovoked                 USA
# 2     2019.08.20  20-Aug-2019  2019  Unprovoked                 USA
# 3     2019.08.16  16-Aug-2019  2019  Unprovoked                 USA
# 4     2019.08.11  11-Aug-2019  2019  Unprovoked                 USA
# ...          ...          ...   ...         ...                 ...
# 6443     ND.0005  Before 1903  0000  Unprovoked           AUSTRALIA
# 6444     ND.0004  Before 1903  0000  Unprovoked           AUSTRALIA
# 6445     ND.0003    1900-1905  0000  Unprovoked                 USA
# 6446     ND.0002    1883-1889  0000  Unprovoked              PANAMA
# 6447     ND.0001    1845-1853  0000  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                                         Location  \
# 0               Florida                 New Smyrna Beach, Volusia County
# ...

# %%
cleaning_data.Data_geoLocation.describe()
# Out:
#          Case Number  Date  Year        Type Country     Area Location  \
# count           6448  6448  6448        6448    6448     6448     6448
# unique          6432  5551   252          11     214      843     4198
# top     1962.06.11.b  1957  2015  Unprovoked     USA  Florida
# freq               2    11   141        4703    2310     1071      546
#
#        Activity  Name   Sex  ...  Time Species Investigator-Source  \
# count      6448  6448  6448  ...  6448    6448                6448
# unique     1545  5341     8  ...   377    1577                5035
# top     Surfing  male     M  ...                    C. Moore, GSAF
# freq       1009   577  5207  ...  3385    2905                 104
#
#                             pdf  \
# count                      6448
# unique                     6438
# top     1921.11.27.a-b-Jack.pdf
# freq                          2
#
#                                              href-formula  \
# ...

# %%
cleaning_data.Data_geoLocation=cleaning_data.fill_Location(Data_geoLocation=cleaning_data.Data_geoLocation)
# Out:
# 25: Data_geoLocation
# adress:South Abaco, The Bahamas
#
# 70: Data_geoLocation
# adress:Girilambone, Bogan Shire Council, New South Wales, 2831, Australia
#
# 91: Data_geoLocation
# adress:Apia, Tuamasaga, Sāmoa
#
# 107: Data_geoLocation
# adress:Downey's Bridge, Gowlane, Municipal District of Macroom, County Cork, Munster, P32 NA02, Éire / Ireland
#
# 108: Data_geoLocation
# adress:Pine Forest Close, Jubilee Gardens Subdivision, Nassau, New Providence, The Bahamas
#
# 193: Data_geoLocation
# adress:Pine Forest Close, Jubilee Gardens Subdivision, Nassau, New Providence, The Bahamas
#
# 199: Data_geoLocation
# 238: Data_geoLocation
# adress:Pine Forest Close, Jubilee Gardens Subdivision, Nassau, New Providence, The Bahamas
#
# 247: Data_geoLocation
# adress:City of Freeport, The Bahamas
#
# 269: Data_geoLocation
# adress:Pine Forest Close, Jubilee Gardens Subdivision, Nassau, New Providence, The Bahamas
#
# 288: Data_geoLocation
# ...

# %%
cleaning_data.Data_geoLocation=cleaning_data.fill_geoLocation(Data_geoLocation=cleaning_data.Data_geoLocation)
# Out:
# ->33: Cook Reef
# geoloc:-17.0542997,168.27513808830548
# ->49: Laohutan Ocean Park Aquarium, Dalian City
# Not find geoloc
#
# ->68: Sandspit Beach, Montaña de Oro State Park
# Not find geoloc
#
# ->69: Southeast of Puerto Peñasco
# Not find geoloc
#
# ->139: La Ticla
# geoloc:18.4546571,-103.5538124
# ->162: Shipwreck’s Beach, Keoneloa Bay, Kauai
# Not find geoloc
#
# ->168: Praia de Sauaçuhy, Maceió
# Not find geoloc
#
# ->199:
# Not find geoloc
#
# ->212: Kama‘ole Beach Park, Maui
# Not find geoloc
#
# ->217: Fort Worth
# geoloc:32.753177,-97.3327459
# ->222: Nofoali’i
# Not find geoloc
#
# ->235: Grao de Moncofa
# geoloc:39.7979847,-0.1321222
# ->259: Sánchez Magallanes, Cárdenas
# geoloc:18.2954949,-93.8613362
# ->267: Playa d’en Bossa
# geoloc:38.8961728,1.415486
# ->374:
# Not find geoloc
#
# ->409:  Côte-Blanche, Nouméa
# geoloc:-22.310142,166.45820784986452
# ->442: Escalerio Beach Balneário Camboriú
# Not find geoloc
#
# ->450: Estaleirinho beach
# ...

# %%
location_empty:Dict=dict()
for v,value in enumerate(cleaning_data.Data_geoLocation.Location):
    if (value == "Missing") or (value is None) or (value==''):
        location_empty[v]=value

# %%
len(location_empty)
# Out:
# 110

# %%
cleaning_data.Data_geoLocation.loc[199]
# Out:
# Case Number                                                 2017.11.13.R
# Date                                                Reported 13-Nov-2017
# Year                                                                2017
# Type                                                          Unprovoked
# Country
# Area
# Location
# Activity                                                         Surfing
# Name                                                       Timur Yunusov
# Sex                                                                    M
# Age                                                                   24
# Injury                                           Puncture wounds to feet
# Fatal(Y/N)                                                             N
# Time
# Species
# Investigator-Source                                            Instagram
# pdf                                               2017.11.13.R-Timur.pdf
# ...

# %%
geoloc_empty:Dict=dict()
for v,value in enumerate(cleaning_data.Data_geoLocation.latitude):
    if (str(value) == "Missing") or (value is None):
        geoloc_empty[v]=value

# %%
len(geoloc_empty)
# Out:
# 201

# %%
cleaning_data.Data_geoLocation.loc[49]
# Out:
# Case Number                                                   2019.04.05
# Date                                                         05-Apr-2019
# Year                                                                2019
# Type                                                            Provoked
# Country                                                            CHINA
# Area                                                   Liaoning Province
# Location                       Laohutan Ocean Park Aquarium, Dalian City
# Activity                                            Diving in shark tank
# Name                                                                Nana
# Sex                                                                    F
# Age
# Injury                               Lacerations to face, chin and scalp
# Fatal(Y/N)                                                             N
# Time
# Species                                                 Sand tiger shark
# ...

# %%
df=cleaning_data.Data_geoLocation
df.shape
# Out:
# (6448, 23)

# %% [markdown]
# ## Save new data

# %%
cleaning_data.Data_geoLocation=dfFloat_to_dfStr(df=cleaning_data.Data_geoLocation)
cleaning_data.Data_geoLocation.describe()
# Out:
#          Case Number  Date  Year        Type Country     Area  \
# count           6448  6448  6448        6448    6448     6448
# unique          6432  5551   252          11     214      843
# top     1962.06.11.b  1957  2015  Unprovoked     USA  Florida
# freq               2    11   141        4703    2310     1071
#
#                                 Location Activity  Name   Sex  ...  Time  \
# count                               6448     6448  6448  6448  ...  6448
# unique                              4424     1545  5341     8  ...   377
# top     New Smyrna Beach, Volusia County  Surfing  male     M  ...
# freq                                 172     1009   577  5207  ...  3385
#
#        Species Investigator-Source                      pdf  \
# count     6448                6448                     6448
# unique    1577                5035                     6438
# top                 C. Moore, GSAF  1921.11.27.a-b-Jack.pdf
# ...

# %%
cleaning_data.Data_geoLocation.describe()
# Out:
#          Case Number  Date  Year        Type Country     Area  \
# count           6448  6448  6448        6448    6448     6448
# unique          6432  5551   252          11     214      843
# top     1962.06.11.b  1957  2015  Unprovoked     USA  Florida
# freq               2    11   141        4703    2310     1071
#
#                                 Location Activity  Name   Sex  ...  Time  \
# count                               6448     6448  6448  6448  ...  6448
# unique                              4424     1545  5341     8  ...   377
# top     New Smyrna Beach, Volusia County  Surfing  male     M  ...
# freq                                 172     1009   577  5207  ...  3385
#
#        Species Investigator-Source                      pdf  \
# count     6448                6448                     6448
# unique    1577                5035                     6438
# top                 C. Moore, GSAF  1921.11.27.a-b-Jack.pdf
# ...

# %%
name_file="sharks"
cleaning_data.Data_geoLocation.to_excel(f'dataNew/{name_file}.xlsx',index=False)
